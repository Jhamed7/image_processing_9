# %%
import cv2 as cv
import matplotlib.pyplot as plt
import numpy as np

# %%
img = cv.imread('files/penguin4.jpeg',0)
img0 = cv.medianBlur(img,5)
ret,th1 = cv.threshold(img0,127,255,cv.THRESH_BINARY)
th2 = cv.adaptiveThreshold(img0,255,cv.ADAPTIVE_THRESH_MEAN_C,\
            cv.THRESH_BINARY,5,2)
th3 = cv.adaptiveThreshold(img0,255,cv.ADAPTIVE_THRESH_GAUSSIAN_C,\
            cv.THRESH_BINARY,7,2)
titles = ['Original Image', 'Global Thresholding (v = 127)',
            'Adaptive Mean Thresholding', 'Adaptive Gaussian Thresholding']
images = [img0, th1, th2, th3]
for i in range(4):
    plt.subplot(2,2,i+1),plt.imshow(images[i],'gray')
    plt.title(titles[i])
    plt.xticks([]),plt.yticks([])
plt.show()

# %%
th1 = 255 - th1

kernel = np.ones((5,5),np.uint8)

closing = cv.dilate(th1,kernel,iterations = 2)
plt.imshow(closing, cmap='gray')

# %%
img= closing
contours, hierarchy = cv.findContours(img, cv.cv2.RETR_EXTERNAL, cv.CHAIN_APPROX_SIMPLE)
# RETR_CCOMP   cv2.RETR_EXTERNAL

counter = 0
for c in contours:
    if len(c)>40:
        counter += 1
        x, y, w, h = cv.boundingRect(c)
        cv.rectangle(img0, (x, y), (x+w, y+h), (255,0,0), 4)
plt.imshow(img0, cmap='gray')
print(f'There are/is {counter} penguin(s) in this picture')
# Out:
# There are/is 5 penguin(s) in this picture

# %% [markdown]
# ## Second picture

# %%
import cv2 as cv
import numpy as np
from matplotlib import pyplot as plt
img = cv.imread('files/penguin1.jpg',0)
ret,thresh1 = cv.threshold(img,127,255,cv.THRESH_BINARY)
ret,thresh2 = cv.threshold(img,127,255,cv.THRESH_BINARY_INV)
ret,thresh3 = cv.threshold(img,127,255,cv.THRESH_TRUNC)
ret,thresh4 = cv.threshold(img,127,255,cv.THRESH_TOZERO)
ret,thresh5 = cv.threshold(img,127,255,cv.THRESH_TOZERO_INV)
titles = ['Original Image','BINARY','BINARY_INV','TRUNC','TOZERO','TOZERO_INV']
images = [img, thresh1, thresh2, thresh3, thresh4, thresh5]
for i in range(6):
    plt.subplot(2,3,i+1),plt.imshow(images[i],'gray',vmin=0,vmax=255)
    plt.title(titles[i])
    plt.xticks([]),plt.yticks([])
plt.show()

# %%
img3 = cv.imread('files/penguin1.jpg',0)
img4 = cv.medianBlur(img3,5)
ret,th21 = cv.threshold(img4,127,255,cv.THRESH_BINARY)
th22 = cv.adaptiveThreshold(img4,255,cv.ADAPTIVE_THRESH_MEAN_C,\
            cv.THRESH_BINARY,3,2)
th23 = cv.adaptiveThreshold(img4,255,cv.ADAPTIVE_THRESH_GAUSSIAN_C,\
            cv.THRESH_BINARY,9,8)
titles = ['Original Image', 'Global Thresholding (v = 127)',
            'Adaptive Mean Thresholding', 'Adaptive Gaussian Thresholding']
images = [img4, th21, th22, th23]
for i in range(4):
    plt.subplot(2,2,i+1),plt.imshow(images[i],'gray')
    plt.title(titles[i])
    plt.xticks([]),plt.yticks([])
plt.show()

# %%
th23 = 255 - th23

kernel = np.ones((5,5),np.uint8)
# closing = cv.morphologyEx(th1, cv.MORPH_OPEN, kernel)
# median1 = cv.medianBlur(th3,3)
closing2 = cv.dilate(th23,kernel,iterations = 1)
plt.imshow(closing2, cmap='gray')

# %%
# img= 255 - th1
img_2= closing2
# img = median
contours_2, hierarchy = cv.findContours(img_2, cv.cv2.RETR_EXTERNAL, cv.CHAIN_APPROX_SIMPLE)
# RETR_CCOMP   cv2.RETR_EXTERNAL

for c in contours_2:
    if len(c)>100:
        x, y, w, h = cv.boundingRect(c)
        cv.rectangle(img4, (x, y), (x+w, y+h), (255,0,0), 4)
plt.imshow(img4, cmap='gray')
